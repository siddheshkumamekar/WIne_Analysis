# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_red = pd.read_csv('F:\DA\python\EDA assignment\winequality-red1.csv')
df_white = pd.read_csv('F:\DA\python\EDA assignment\winequality-white1.csv')

# %%
print(df_red.sample(5),df_white.sample(5))
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 913             9.4             0.395         0.46             4.6      0.094
# 1032            8.1             0.820         0.00             4.1      0.095
# 516            12.5             0.600         0.49             4.3      0.100
# 1007            9.1             0.300         0.34             2.0      0.064
# 1310            7.5             0.610         0.26             1.9      0.073
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 913                   3.0                  10.0  0.99639  3.27       0.64
# 1032                  5.0                  14.0  0.99854  3.36       0.53
# 516                   5.0                  14.0  1.00100  3.25       0.74
# 1007                 12.0                  25.0  0.99516  3.26       0.84
# 1310                 24.0                  88.0  0.99612  3.30       0.53
#
#       alcohol  quality
# 913      12.2        7
# ...

# %%
print(df_red.info(),df_white.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# ...

# %%
df_red.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df_red.iloc[100:111,:]
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 100            8.3             0.610         0.30             2.1      0.084
# 101            7.8             0.500         0.30             1.9      0.075
# 102            8.1             0.545         0.18             1.9      0.080
# 103            8.1             0.575         0.22             2.1      0.077
# 104            7.2             0.490         0.24             2.2      0.070
# 105            8.1             0.575         0.22             2.1      0.077
# 106            7.8             0.410         0.68             1.7      0.467
# 107            6.2             0.630         0.31             1.7      0.088
# 108            8.0             0.330         0.53             2.5      0.091
# 109            8.1             0.785         0.52             2.0      0.122
# 110            7.8             0.560         0.19             1.8      0.104
#
# ...

# %%
df_red['quality'].unique(),df_white['quality'].unique()
# Out:
# (array([5, 6, 7, 4, 8, 3], dtype=int64),
#  array([6, 5, 7, 8, 4, 3, 9], dtype=int64))

# %%
df_red.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df_white.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# 1. df_ red has 1599 entries where as df_ white 4899 entries.
# 2. There are no empty cells in either of the dataset as we can see above.
# 3. All the columns have have values in float or int.
# 4. There are 12 columns in total for both dataset, below we can see the list of column names for respective dataset.

# %%
print(df_red.columns,df_white.columns)
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object') Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df_red.corr(),annot= True,cmap ='YlGnBu');

# %%
sub_red_df = df_red.iloc[:,[0,11,8,2,7,10,9]]
sub_red_df
# Out:
#       fixed acidity  quality    pH  citric acid  density  alcohol  sulphates
# 0               7.4        5  3.51         0.00  0.99780      9.4       0.56
# 1               7.8        5  3.20         0.00  0.99680      9.8       0.68
# 2               7.8        5  3.26         0.04  0.99700      9.8       0.65
# 3              11.2        6  3.16         0.56  0.99800      9.8       0.58
# 4               7.4        5  3.51         0.00  0.99780      9.4       0.56
# ...             ...      ...   ...          ...      ...      ...        ...
# 1594            6.2        5  3.45         0.08  0.99490     10.5       0.58
# 1595            5.9        6  3.52         0.10  0.99512     11.2       0.76
# 1596            6.3        6  3.42         0.13  0.99574     11.0       0.75
# 1597            5.9        5  3.57         0.12  0.99547     10.2       0.71
# 1598            6.0        6  3.39         0.47  0.99549     11.0       0.66
#
# [1599 rows x 7 columns]

# %%
sns.pairplot(sub_red_df);

# %%
plt.figure(figsize=(10,8))
plt.subplot(3,2,1)
sns.barplot(x='quality',y='alcohol',data=df_red)
plt.title('Alcohol vs Quality');
plt.subplot(3,2,2)
sns.lineplot(x='pH',y='alcohol',data=df_red)
plt.title('Alcohol vs ph')
plt.subplot(3,2,3)
sns.scatterplot(x='fixed acidity',y='citric acid',data= df_red) 
plt.subplot(3,2,4)
sns.lineplot(x='fixed acidity',y='citric acid',data= df_red) 
plt.subplot(3,2,5)
sns.scatterplot(x='fixed acidity',y='density',data= df_red)
plt.tight_layout(pad=1);

# %% [markdown]
# 8- a.Yes, alcohol is decently correlated with alchohol as seen from heatmap and above bar graph.
#    b.Yes, alcohol has weak positive correlation with ph vale as per heatmap.
#    c.Yes,Citric acid and density have a strong positive correlation with fixed acidity which is of 0.67.
#    d.Yes,pH has a negative correlation with density, fixed acidity, citric acid, and sulfates as per heatmap

# %%
sns.barplot(x='quality',y='fixed acidity',data=df_red);

# %% [markdown]
# As seen from the above graph Quality of red wine is barely dependent on Fixed acidity.

# %%
sns.barplot(x='quality',y= 'free sulfur dioxide',data=df_red);

# %%
sns.countplot(x='quality',data= df_red);

# %% [markdown]
# from above graph we can figure out that wine samples of decent quality are more since count of 5 and 6 is more.

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x='quality',y='alcohol',data=df_red);

# %% [markdown]
# As we see in the graph the quality of red wine tends to increase with increase in alcohol concentration.
# Also there are few outlyers with samples of quality in 5,6 and 3 ; decent quality samples have quite outliers

# %%
sns.jointplot(x='alcohol',y='pH',data= df_red)

# %%
from scipy import stats
stats.pearsonr(df_red['alcohol'], df_red['pH'])
# Out:
# (0.2056325085124209, 9.964497717485909e-17)

# %%
sns.lmplot(x='alcohol', y='pH', data=df_red);

# %%
#get_correlation = lambda x,y: df_red['x'].corr(df_red['y'])

# %%
a=input("name of the first column:")
b=input("name of the second column:")
def get_correlation(a,b):
    corr =df_red[a].corr(df_red[b])
    print(f"The correlation between {a} and {b} is {corr}")
get_correlation(a,b)
# Out:
# name of the first column:volatile acidity
# name of the second column:citric acid
# The correlation between volatile acidity and citric acid is -0.5524956845595801

# %%
df_red.alcohol.corr(df_red.pH)
# Out:
# 0.20563250851242013

# %%
df_white.sample(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4333            7.3             0.190         0.27            13.9      0.057
# 2787            6.4             0.240         0.25            20.2      0.083
# 2963            7.5             0.380         0.29             4.9      0.021
# 4109            5.0             0.255         0.22             2.7      0.043
# 2486            6.7             0.240         0.32            10.3      0.079
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4333                 45.0                 155.0  0.99807  2.94       0.41
# 2787                 35.0                 157.0  0.99976  3.17       0.50
# 2963                 38.0                 113.0  0.99026  3.08       0.48
# 4109                 46.0                 153.0  0.99238  3.75       0.76
# 2486                 37.0                 122.0  0.99662  3.02       0.45
#
#       alcohol  quality
# 4333      8.8        8
# ...

# %%
print(df_white['quality'].mean(),df_white['quality'].mean())
# Out:
# 5.87790935075541 5.87790935075541

# %%
#alcohol_avg = df_red.groupby(df_red['quality'])['alcohol'].mean()

# %%
print(df_white['quality'].unique(),df_red['quality'].unique())
# Out:
# [6 5 7 8 4 3 9] [5 6 7 4 8 3]

# %%
df_white.sort_values(by=['quality'])
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3307            9.4              0.24         0.29             8.5      0.037
# 445             7.1              0.32         0.32            11.0      0.038
# 2050           11.8              0.23         0.38            11.1      0.034
# 3810            6.8              0.26         0.34            15.1      0.060
# 3409            6.2              0.23         0.35             0.7      0.051
# ...             ...               ...          ...             ...        ...
# 774             9.1              0.27         0.45            10.6      0.035
# 827             7.4              0.24         0.36             2.0      0.031
# 876             6.9              0.36         0.34             4.2      0.018
# 820             6.6              0.36         0.29             1.6      0.021
# 1605            7.1              0.26         0.49             2.2      0.032
#
# ...

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.countplot(x='quality',data= df_red)
plt.title('red wine quality count')
plt.subplot(1,2,2)
sns.countplot(x='quality',data= df_white)
plt.title('white wine quality count');

# %%
df_red['wine category']= df_red['quality'].apply(lambda x :'low' if x <= 5 else ('medium' if x>5 and x<=7 else 'high' ))
df_red.sample(8)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 33              6.9             0.605         0.12            10.7      0.073
# 399             8.7             0.765         0.22             2.3      0.064
# 619            11.3             0.370         0.41             2.3      0.088
# 1250            7.1             0.600         0.01             2.3      0.079
# 385             7.4             0.630         0.07             2.4      0.090
# 976             7.2             0.410         0.30             2.1      0.083
# 607             8.8             0.480         0.41             3.3      0.092
# 807             8.2             0.280         0.40             2.4      0.052
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 33                   40.0                  83.0  0.99930  3.45       0.52
# 399                   9.0                  42.0  0.99630  3.10       0.55
# ...

# %%
df_white['wine category']= df_white['quality'].apply(lambda x :'low' if x <= 5 else ('medium' if x>5 and x<=7 else 'high' ))
df_white.sample(8)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2566            6.9             0.210         0.24            1.80      0.021
# 4648            6.7             0.610         0.21            1.65      0.117
# 1775            7.7             0.490         1.00           19.60      0.030
# 1759            6.6             0.620         0.20            8.70      0.046
# 4470            4.7             0.145         0.29            1.00      0.042
# 2612            6.7             0.300         0.29            2.80      0.025
# 911             6.2             0.330         0.19            5.60      0.042
# 3729            7.5             0.280         0.41            1.30      0.044
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2566                 17.0                  80.0  0.98992  3.15       0.46
# 4648                 40.0                 240.0  0.99380  3.11       0.57
# ...

# %%
#df_red.loc[df_red['wine category']== 'high']

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.countplot(x='wine category',data= df_red)
plt.title('red wine category count')
plt.subplot(1,2,2)
sns.countplot(x='wine category',data= df_white)
plt.title('white wine category count');

# %%
#df_wines = pd.concat([df_red,df_white]) 
#df_wines

# %%
#df_wines.drop(index=[1],axis=1,inplace= True)
#df_white.drop(columns=['white'],axis=1,inplace= True)

# %%
df_red['label'] = 'red'
df_white['label']= 'white'

# %%
df_wines = pd.concat([df_red,df_white],ignore_index= True)
df_wines
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df_wines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  wine category         6497 non-null   object
#  13  label                 6497 non-null   object
# dtypes: float64(11), int64(1), object(2)
# ...

# %%
df_wines.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
df_wines.sample(frac=1)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3609            7.0              0.25         0.56             2.0      0.035
# 123             8.0              0.71         0.00             2.6      0.080
# 2421            6.8              0.18         0.21             5.4      0.053
# 68              9.3              0.32         0.57             2.0      0.074
# 238             7.2              0.63         0.00             1.9      0.097
# ...             ...               ...          ...             ...        ...
# 3757            7.4              0.18         0.27             1.3      0.048
# 6346            5.6              0.26         0.50            11.4      0.029
# 4575            6.8              0.32         0.39             9.6      0.026
# 296            10.6              0.83         0.37             2.6      0.086
# 3502            7.8              0.34         0.27             1.2      0.040
#
# ...

# %%
quality_avg = df_red.groupby(df_wines['quality']).agg({'alcohol':'mean','residual sugar' : ['mean','max','min']})

# %%
quality_avg
# Out:
#            alcohol residual sugar
#               mean           mean   max  min
# quality
# 3         9.955000       2.635000   5.7  1.2
# 4        10.265094       2.694340  12.9  1.3
# 5         9.899706       2.528855  15.5  1.2
# 6        10.629519       2.477194  15.4  0.9
# 7        11.465913       2.720603   8.9  1.2
# 8        12.094444       2.577778   6.4  1.4

# %%
wines_df = df_wines.iloc[:,[7,8,10,11,12]]

# %%
df_low = wines_df[wines_df['wine category']=='low']
df_medium = wines_df[wines_df['wine category']=='medium']
df_high = wines_df[wines_df['wine category']=='high']

# %%
wines_new_df = pd.concat([df_high,df_medium,df_low])

# %%
wines_new_df
# Out:
#       density    pH  alcohol  quality wine category
# 267   0.99730  3.35     12.8        8          high
# 278   0.99760  3.23     12.6        8          high
# 390   0.99240  3.56     12.9        8          high
# 440   0.99870  2.88      9.8        8          high
# 455   0.99880  3.22     13.4        8          high
# ...       ...   ...      ...      ...           ...
# 6481  0.99184  3.26     10.7        5           low
# 6483  0.99492  3.14      9.6        5           low
# 6487  0.99330  3.04      9.2        5           low
# 6491  0.99298  3.29      9.7        5           low
# 6493  0.99490  3.15      9.6        5           low
#
# [6497 rows x 5 columns]

# %%
wines_new_df.corr()
# Out:
#           density        pH   alcohol   quality
# density  1.000000  0.011686 -0.686745 -0.305858
# pH       0.011686  1.000000  0.121248  0.019506
# alcohol -0.686745  0.121248  1.000000  0.444319
# quality -0.305858  0.019506  0.444319  1.000000

# %% [markdown]
# as seen from above correlation ph and alcohol are correlated with quality in very less and decent way respectively.

# %%
sns.scatterplot(x= 'alcohol',y=wines_new_df.index,data=wines_new_df,hue='wine category')
plt.title('Category analysis with respect to Alcohol (univariate)');

# %% [markdown]
# univariate analysis with respectto alchol

# %%
#sns.scatterplot(x= 'pH',y='alcohol',data=wines_new_df,hue='wine category');

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df_wines.corr(),annot=True, cmap = 'Greens');

# %%
sns.countplot(x='wine category',data= df_wines);
